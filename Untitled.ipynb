# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/CC/OneDrive/Desktop/Siphoh/dataset - 2020-09-24.csv')

# %%
print(df.columns)
# Out:
# Index(['Name', 'Jersey Number', 'Club', 'Position', 'Nationality', 'Age',
#        'Appearances', 'Wins', 'Losses', 'Goals', 'Goals per match',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target',
#        'Shooting accuracy %', 'Hit woodwork', 'Big chances missed',
#        'Clean sheets', 'Goals conceded', 'Tackles', 'Tackle success %',
#        'Last man tackles', 'Blocked shots', 'Interceptions', 'Clearances',
#        'Headed Clearance', 'Clearances off line', 'Recoveries', 'Duels won',
#        'Duels lost', 'Successful 50/50s', 'Aerial battles won',
#        'Aerial battles lost', 'Own goals', 'Errors leading to goal', 'Assists',
#        'Passes', 'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls', 'Saves',
#        'Penalties saved', 'Punches', 'High Claims', 'Catches',
# ...

# %%
Name = df['Name'].loc[10:14]
JerseyNum = df['Jersey Number'].loc[10:14]

# %%
plt.figure(figsize=(10,5))
plt.bar(Name, JerseyNum, color='red', alpha=0.7)
plt.title('Player name and jersey number')
plt.xlabel('Player Names')
plt.ylabel('Jersey Number')
plt.show()

# %%
data = np.random.normal(loc=20.0, scale=5.0, size=365)

plt.hist(data, bins=20, color='pink', alpha=0.7)
# Out:
# (array([ 2.,  3.,  5.,  3.,  5., 11., 21., 32., 28., 38., 39., 42., 34.,
#         28., 28., 22., 14.,  7.,  0.,  3.]),
#  array([ 4.22738222,  5.70560775,  7.18383329,  8.66205882, 10.14028435,
#         11.61850988, 13.09673542, 14.57496095, 16.05318648, 17.53141201,
#         19.00963755, 20.48786308, 21.96608861, 23.44431414, 24.92253967,
#         26.40076521, 27.87899074, 29.35721627, 30.8354418 , 32.31366734,
#         33.79189287]),
#  <BarContainer object of 20 artists>)

# %%
modules = ['TP', 'IS', 'DS', 'ITS']
scores = [30, 30, 20, 20]

# %%
plt.pie(scores, labels=modules, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x29572d33ad0>,
# ...
#  [Text(-1.067325288937436, -0.26611412513171634, 'TP'),
#   Text(0.582911295464512, -0.9328528402807618, 'IS'),
#   Text(0.9328528129927135, 0.5829113391345049, 'DS'),
#   Text(-0.26611427502702273, 1.0673252515643215, 'ITS')],
#  [Text(-0.5821774303295105, -0.14515315916275437, '30.0%'),
#   Text(0.3179516157079156, -0.5088288219713245, '30.0%'),
#   Text(0.5088288070869346, 0.3179516395279117, '20.0%'),
#   Text(-0.14515324092383056, 0.5821774099441753, '20.0%')])
