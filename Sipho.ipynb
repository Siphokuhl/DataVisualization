# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(df.duplicated().sum())
print(df.shape)

# %%
df = pd.read_csv('C:/Users/Owamii Siphokuhle/Downloads/dataset - 2020-09-24.csv')
data = np.random.normal(loc=20.0, scale=5.0, size=365)
plt.hist(data,bins=20,color='Green', alpha=0.7)
plt.title('Histo plot of Name vs Position')
plt.xlabel('Name')
plt.ylabel('Position')
plt.show()

# %%
df = pd.read_csv('C:/Users/Owamii Siphokuhle/Downloads/dataset - 2020-09-24.csv')
plt.scatter(df['Name'], df['Position'])
plt.title('Scatter plot of name vs Position')
plt.xlabel('Name')
plt.ylabel('Position')
plt.show()

# %%
Name=['Sethu','Zinhle','Skhona','Muzi']
brands=['Nike','Puma','Adidas','Ellese']

# %%
plt.figure(figsize=(7,7))
plt.bar(Name,brands,color='blue',alpha=0.7)
plt.title('Position vs brands')
plt.xlabel('Name')
plt.ylabel('brands')
plt.show()

# %%
Names=['Sipho','Sakhi','Bheki',]
Position=[30,40,50,]

# %%
plt.figure(figsize=(7,7))
plt.pie(Position,labels=Names,autopct='%1.1f%%',startangle=140)
plt.title('Names and Positions')
plt.show()
